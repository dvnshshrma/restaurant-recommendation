# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
testInputs= ['good ambiance restaurants, serving fish',
'restaurants serving hygienic food',
'must visit restaurants have fish',
'restaurants serving healthy food near Airport',
'restaurants with good dance floor and music',
'best cakes',
'authentic chicken biryani under Rs 200']

doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
labels = {}

for s in testInputs:
    doc1 = nlp(s)
    labels[s] = []
    for ent in doc1.ents:
        labels[s].append(ent.label_)

labels
# Out:
# {'good ambiance restaurants, serving fish': [],
#  'restaurants serving hygienic food': [],
#  'must visit restaurants': [],
#  'restaurants serving healthy food near Airport': ['GPE'],
#  'restaurants with good dance floor and music': [],
#  'best cakes': [],
#  'authentic chicken biryani under Rs 200': ['PERSON', 'CARDINAL']}

# %%
pos = {}
for s in testInputs:
    doc1 = nlp(s)
    for token in doc1:
        print (token.text)
        print ("--------------------------------------")
        print(token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha)
        if 'NN' in token.tag_ and token.is_stop == False:
            pos[token.text] = [token.tag_, token.dep_]
    print ("---------------------------------------")
print ("---------------------------------------")
print (pos)
for k in pos:
    print (k)
    list(pos[k]).append(nlp(k).ents)
# Out:
# good
# --------------------------------------
# good ADJ JJ amod xxxx True
# ambiance
# --------------------------------------
# ambiance NOUN NN compound xxxx True
# restaurants
# --------------------------------------
# restaurant NOUN NNS ROOT xxxx True
# ,
# --------------------------------------
# , PUNCT , punct , False
# serving
# --------------------------------------
# serve VERB VBG acl xxxx True
# fish
# --------------------------------------
# fish NOUN NN dobj xxxx True
# ---------------------------------------
# restaurants
# --------------------------------------
# restaurant NOUN NNS ROOT xxxx True
# serving
# --------------------------------------
# serve VERB VBG acl xxxx True
# hygienic
# --------------------------------------
# hygienic ADJ JJ amod xxxx True
# food
# --------------------------------------
# food NOUN NN dobj xxxx True
# ---------------------------------------
# must
# --------------------------------------
# must VERB MD aux xxxx True
# visit
# --------------------------------------
# visit VERB VB ROOT xxxx True
# restaurants
# --------------------------------------
# restaurant NOUN NNS dobj xxxx True
# ---------------------------------------
# restaurants
# --------------------------------------
# restaurant NOUN NNS ROOT xxxx True
# serving
# --------------------------------------
# serve VERB VBG acl xxxx True
# healthy
# --------------------------------------
# healthy ADJ JJ amod xxxx True
# food
# --------------------------------------
# food NOUN NN dobj xxxx True
# near
# --------------------------------------
# near ADP IN prep xxxx True
# Airport
# --------------------------------------
# airport PROPN NNP pobj Xxxxx True
# ---------------------------------------
# restaurants
# --------------------------------------
# restaurant NOUN NNS ROOT xxxx True
# with
# --------------------------------------
# with ADP IN prep xxxx True
# good
# --------------------------------------
# good ADJ JJ amod xxxx True
# dance
# --------------------------------------
# dance NOUN NN compound xxxx True
# floor
# --------------------------------------
# floor NOUN NN pobj xxxx True
# and
# --------------------------------------
# and CCONJ CC cc xxx True
# music
# --------------------------------------
# music NOUN NN conj xxxx True
# ---------------------------------------
# best
# --------------------------------------
# good ADJ JJS amod xxxx True
# cakes
# --------------------------------------
# cake NOUN NNS ROOT xxxx True
# ---------------------------------------
# authentic
# --------------------------------------
# authentic ADJ JJ amod xxxx True
# chicken
# --------------------------------------
# chicken NOUN NN nsubj xxxx True
# biryani
# --------------------------------------
# biryani NOUN NNS ROOT xxxx True
# under
# --------------------------------------
# under ADP IN prep xxxx True
# Rs
# --------------------------------------
# r NOUN NNS pobj Xx True
# 200
# --------------------------------------
# 200 NUM CD nummod ddd False
# ---------------------------------------
# ---------------------------------------
# {'ambiance': ['NN', 'compound'], 'restaurants': ['NNS', 'ROOT'], 'fish': ['NN', 'dobj'], 'food': ['NN', 'dobj'], 'Airport': ['NNP', 'pobj'], 'dance': ['NN', 'compound'], 'floor': ['NN', 'pobj'], 'music': ['NN', 'conj'], 'cakes': ['NNS', 'ROOT'], 'chicken': ['NN', 'nsubj'], 'biryani': ['NNS', 'ROOT'], 'Rs': ['NNS', 'pobj']}
# ambiance
# restaurants
# fish
# food
# Airport
# dance
# floor
# music
# cakes
# chicken
# biryani
# Rs

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
pos
# Out:
# {'ambiance': ['NN', 'compound'],
#  'restaurants': ['NNS', 'ROOT'],
#  'fish': ['NN', 'dobj'],
#  'food': ['NN', 'dobj'],
#  'Airport': ['NNP', 'pobj'],
#  'dance': ['NN', 'compound'],
#  'floor': ['NN', 'pobj'],
#  'music': ['NN', 'conj'],
#  'cakes': ['NNS', 'ROOT'],
#  'chicken': ['NN', 'nsubj'],
#  'biryani': ['NNS', 'ROOT'],
#  'Rs': ['NNS', 'pobj']}

# %%
# token level
ent_ada_0 = [doc[0].text, doc[0].ent_type_]
ent_ada_1 = [doc[1].text, doc[1].ent_type_]
ent_london_5 = [doc[5].text, doc[5].ent_type_]
print(ent_ada_0)  # ['Ada', 'PERSON', 'Q7259']
print(ent_ada_1)  # ['Lovelace', 'PERSON', 'Q7259']
print(ent_london_5)  # ['London', 'GPE', 'Q84']
# Out:
# ['Apple', 'ORG']
# ['is', '']
# ['U.K.', 'GPE']

# %%
## removing Stop Words
import stanza
stanza.download('en')       # This downloads the English models for the neural pipeline
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
doc = nlp("Barack Obama was born in Hawaii.  He was elected president in 2008.")
doc.sentences[0].print_dependencies()
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.1.0.json: 122kB [00:00, 14.0MB/s]
# 2020-11-27 22:06:31 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.1.0/en/default.zip: 100%|██████████| 428M/428M [10:09<00:00, 702kB/s]
# 2020-11-27 22:16:54 INFO: Finished downloading models and saved to /Users/devanshsharma/stanza_resources.
# 2020-11-27 22:16:54 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2020-11-27 22:16:54 INFO: Use device: cpu
# 2020-11-27 22:16:54 INFO: Loading: tokenize
# 2020-11-27 22:16:54 INFO: Loading: pos
# 2020-11-27 22:16:55 INFO: Loading: lemma
# 2020-11-27 22:16:55 INFO: Loading: depparse
# 2020-11-27 22:16:57 INFO: Loading: sentiment
# 2020-11-27 22:16:58 INFO: Loading: ner
# 2020-11-27 22:16:59 INFO: Done loading processors!
# ('Barack', 4, 'nsubj:pass')
# ('Obama', 1, 'flat')
# ('was', 4, 'aux:pass')
# ('born', 0, 'root')
# ('in', 6, 'case')
# ('Hawaii', 4, 'obl')
# ('.', 4, 'punct')

# %%
doc = nlp("Barack Obama was born in Hawaii.  He was elected president in 2008.")
doc.sentences[0].print_dependencies()
# Out:
# ('Barack', 4, 'nsubj:pass')
# ('Obama', 1, 'flat')
# ('was', 4, 'aux:pass')
# ('born', 0, 'root')
# ('in', 6, 'case')
# ('Hawaii', 4, 'obl')
# ('.', 4, 'punct')

# %%
doc.sentences[0]
# Out:
# [
#   {
#     "id": 1,
#     "text": "Barack",
#     "lemma": "Barack",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 4,
#     "deprel": "nsubj:pass",
#     "misc": "start_char=0|end_char=6",
#     "ner": "B-PERSON"
#   },
#   {
#     "id": 2,
#     "text": "Obama",
#     "lemma": "Obama",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 1,
#     "deprel": "flat",
#     "misc": "start_char=7|end_char=12",
#     "ner": "E-PERSON"
#   },
#   {
#     "id": 3,
#     "text": "was",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 4,
#     "deprel": "aux:pass",
#     "misc": "start_char=13|end_char=16",
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "born",
#     "lemma": "bear",
#     "upos": "VERB",
#     "xpos": "VBN",
#     "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#     "head": 0,
#     "deprel": "root",
#     "misc": "start_char=17|end_char=21",
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "in",
#     "lemma": "in",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 6,
#     "deprel": "case",
#     "misc": "start_char=22|end_char=24",
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "Hawaii",
#     "lemma": "Hawaii",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "misc": "start_char=25|end_char=31",
#     "ner": "S-GPE"
#   },
#   {
#     "id": 7,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 4,
#     "deprel": "punct",
#     "misc": "start_char=31|end_char=32",
#     "ner": "O"
#   }
# ]

# %%
from nltk.corpus import stopwords  
from nltk.tokenize import word_tokenize  
  
example_sent = """This is a sample sentence, 
                  showing off the stop words filtration."""
  
stop_words = set(stopwords.words('english'))  
  
word_tokens = word_tokenize(example_sent)  
  
filtered_sentence = [w for w in word_tokens if not w in stop_words]  
  
filtered_sentence = []  
  
for w in word_tokens:  
    if w not in stop_words:  
        filtered_sentence.append(w)  
  
print(word_tokens)  
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
## After cleaning stop words


## Getting Data

## find integers from the text 

## lets get some string data that contains food 
import pandas as pd 
df = pd.read_csv('dataPreprocessedRest.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'online_order', 'book_table', 'votes', 'location',
#        'dish_liked', 'cuisines', 'approx_cost(for two people)', 'menu_item',
#        'rate', 'type', 'reviews1', 'num_reviews'],
#       dtype='object')

# %%
df['dish_liked'][2].split(',')
# Out:
# ['Icecream Cake',
#  ' Brownie',
#  ' Waffles',
#  ' Chocolate Icecreams',
#  ' Thick Shakes']

# %%
s = df['dish_liked'].dropna().reset_index()

# %%
s['dishArr'] = s['dish_liked'].apply(lambda x: list(set(x.split(','))))

# %%
s['dish_liked'][0]
# Out:
# 'Icecream Cake, Brownie, Waffles, Chocolate Icecreams, Thick Shakes'

# %%
len(s['dishArr'][0])
# Out:
# 5

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'online_order', 'book_table', 'votes', 'location',
#        'dish_liked', 'cuisines', 'approx_cost(for two people)', 'menu_item',
#        'rate', 'type', 'reviews1', 'num_reviews'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                          name online_order book_table  votes  \
# 0           0        Unique Brew Cafe Resto           No         No      0
# 1           1                Jayanthi Sagar           No         No     21
# 2           2  Rock Stone Ice Cream Factory          Yes         No    131
# 3           3         Punjabi by Nature 2.0           No         No   3236
# 4           4             Rayalaseema Chefs          Yes        Yes    225
#
#                 location                                         dish_liked  \
# 0            Indiranagar                                                NaN
# 1  Koramangala 5th Block                                                NaN
# 2                    BTM  Icecream Cake, Brownie, Waffles, Chocolate Ice...
# 3                    BTM  Paneer Tikki, Mutton Raan, Mango Margarita, Cr...
# 4           Marathahalli  Bamboo Chicken, Butter Naan, Mutton Biryani, P...
#
#                                  cuisines approx_cost(for two people)  \
# 0                               Fast Food                         200
# 1     South Indian, North Indian, Chinese                         200
# 2                               Ice Cream                         230
# 3                            North Indian                         NaN
# 4  North Indian, Biryani, Andhra, Chinese                         800
#
#                                            menu_item  rate  \
# 0                                                 []   3.9
# 1                                                 []   3.1
# 2  ['Midnight Indulgence Cake', 'Butterscotch Mel...   4.0
# 3                                                 []   4.2
# 4                                                 []   3.9
#
#                   type                                           reviews1  \
# 0  Dine-out & Desserts                                                 []
# 1  Dine-out & Desserts  ['Rated 2.0 RATEDn  Works only because its che...
# 2             Delivery  ['Rated 4.0 RATEDn  Ice creams are really tast...
# 3             Delivery  ['Rated 3.0 RATEDn  It has a beautiful ambianc...
# 4             Delivery  ['Rated 5.0 RATEDn  Had Good experience with t...
#
#    num_reviews
# 0            0
# 1           13
# 2            8
# 3          139
# 4            4

# %%
## Food library NLTK 

from nltk.corpus import wordnet as wn
food = wn.synset('food.n.02')

# %%
foodList = list(set([w for s in food.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))

# %%
foodList
# Out:
# ['round_steak',
#  'offal',
#  'Nova_lox',
#  'blade_roast',
#  "calves'_feet",
#  'Sally_Lunn',
#  'top_round',
#  'Berlin_doughnut',
#  'sinker',
#  'sugar_snap_pea',
#  'roast_lamb',
#  'fortune_cookie',
#  'grape',
#  'hindquarter',
#  'cherimolla',
#  'Concord_grape',
#  'bread',
#  'grey_mullet',
#  'cauliflower',
#  'shadberry',
#  'leek',
#  'Bavarian_blue',
#  'brick_cheese',
#  'ruggelach',
#  'sour_bread',
#  'babka',
#  'currant',
#  'corn_dab',
#  'bratwurst',
#  'scuppernong',
#  'fresh_food',
#  'Nova_Scotia_lox',
#  'soft_roll',
#  'black-eyed_pea',
#  'Catawba',
#  'smelt',
#  'tagliatelle',
#  'winkle',
#  'Vienna_sausage',
#  'beigel',
#  'crab',
#  'sirloin',
#  'loaf',
#  'Yellow_Delicious',
#  'fritter',
#  'frumenty',
#  'pea',
#  'rack',
#  "farmer's_cheese",
#  'wedding_cake',
#  'dandelion_green',
#  'bay_scallop',
#  'soy',
#  'luncheon_meat',
#  'baba_au_rhum',
#  'anchovy_pear',
#  'puffed_rice',
#  'red_onion',
#  'runner_bean',
#  'smallmouth_bass',
#  'banana_bread',
#  'beef_roast',
#  'honeydew',
#  'tenderloin',
#  'side',
#  'finnan_haddie',
#  'flapjack',
#  'journey_cake',
#  'scollop',
#  'sweetbreads',
#  'wienerwurst',
#  'raisin_bread',
#  'sapodilla_plum',
#  'water_lemon',
#  'summer_squash',
#  'pomegranate',
#  'salad_greens',
#  'goa_bean',
#  'Gouda',
#  'whole_wheat_bread',
#  'kaiser_roll',
#  'tortellini',
#  'crisphead_lettuce',
#  'acorn_squash',
#  'snap_bean',
#  'side_of_bacon',
#  'chopsteak',
#  'frier',
#  'stockfish',
#  'rabbit',
#  'guinea_hen',
#  'acerola',
#  'eclair',
#  'ackee',
#  'langoustine',
#  'mustard_greens',
#  'mulberry',
#  'codfish',
#  'dark_chocolate',
#  'sparerib',
#  'apple_tart',
#  'loin',
#  'lobster',
#  'bluefin',
#  'brook_trout',
#  'scallop',
#  'coho_salmon',
#  'convenience_food',
#  'beignet',
#  'chuck_short_ribs',
#  'potherb',
#  "calves'_liver",
#  'seed_cake',
#  'chile',
#  'onion_roll',
#  'pilchard',
#  'chop_steak',
#  'scup',
#  'red_meat',
#  'shortcake',
#  'radish',
#  'cayenne',
#  'truffle',
#  'hominy_grits',
#  'sausage_roll',
#  'haricot_vert',
#  'aubergine',
#  'cottage_cheese',
#  'sugar_pea',
#  'caramel_bun',
#  'crookneck_squash',
#  'seeded_raisin',
#  'pompano',
#  'tuna',
#  'pickled_herring',
#  'shallot',
#  'Alaskan_king_crab',
#  'jerked_meat',
#  'tart',
#  'lingcod',
#  'shellfish',
#  'pimiento',
#  'European_blueberry',
#  'whiting',
#  'beef_tongue',
#  'McIntosh',
#  'Vienna_roll',
#  'green_soybean',
#  'minute_steak',
#  'flannel_cake',
#  'granadilla',
#  'wiener',
#  'partridge',
#  'pineapple_guava',
#  'matzo_ball',
#  'bluefish',
#  'aitchbone',
#  'plumcot',
#  'sour_cherry',
#  "pigs'_feet",
#  'chitlings',
#  'beefsteak_tomato',
#  'Irish_potato',
#  'pastrami',
#  'quiche_Lorraine',
#  'celeriac',
#  'lunch_meat',
#  'white_bean',
#  'flame_tokay',
#  'peach',
#  'muscadine',
#  'greengage_plum',
#  'danish',
#  'lobster_tart',
#  'Nova_salmon',
#  'crepe',
#  'steamer',
#  'cling',
#  'pollack',
#  'sockeye',
#  'breast_of_lamb',
#  'Jamaica_apple',
#  'blackheart',
#  'puffed_wheat',
#  'ready-mix',
#  'slipskin_grape',
#  'Spanish_mackerel',
#  'winter_flounder',
#  'cornmeal_mush',
#  'toast',
#  'bonito',
#  'grey_sole',
#  'chuck',
#  'shaddock',
#  'fugu',
#  'double_Gloucester',
#  'flat_bone',
#  'butter_cookie',
#  'fox_grape',
#  'cherrystone_clam',
#  'rugulah',
#  'birthday_cake',
#  'petit_four',
#  'gorgonzola',
#  'hard_roll',
#  'albacore',
#  'mammee_apple',
#  'damson_plum',
#  'frank',
#  'sour_orange',
#  'mangel-wurzel',
#  'sapsago',
#  'fish',
#  'milk_chocolate',
#  'Thompson_Seedless',
#  'butter',
#  'goose_liver',
#  'Shawnee_cake',
#  'sailfish',
#  'mullet',
#  'roast',
#  'bosc',
#  'sour_gourd',
#  'manicotti',
#  'mutton',
#  'kingfish',
#  'oyster_plant',
#  'iceberg',
#  'yam',
#  'anchovy',
#  'seckel',
#  'net_melon',
#  'mammee',
#  'black_salsify',
#  'cocoa_plum',
#  'bluefin_tuna',
#  'cusk',
#  'head_cabbage',
#  'breakfast_food',
#  'cherrystone',
#  'oxheart_cherry',
#  'brandysnap',
#  'Camembert',
#  'oatcake',
#  'chapati',
#  'littleneck',
#  'black_pudding',
#  'salt_pork',
#  'marrow',
#  'cooky',
#  'garbanzo',
#  'sea_trout',
#  'fresh_foods',
#  'barmbrack',
#  'Bologna_sausage',
#  'chocolate',
#  'cinnamon_roll',
#  'Hershey_bar',
#  'dog_biscuit',
#  'brownie',
#  'beet',
#  'won_ton',
#  'gigot',
#  'turnip_greens',
#  'veal',
#  'breadfruit',
#  'flatbrod',
#  'sapote',
#  'globe_pepper',
#  'trout',
#  'turbot',
#  'short_ribs',
#  'kale',
#  'cowpea',
#  'edda',
#  'heart_cherry',
#  'coffeecake',
#  'broiler',
#  'hallah',
#  'cisco',
#  'butterfish',
#  'matzo',
#  'rose_apple',
#  'soft-shell_clam',
#  'grits',
#  'Mexican_black_cherry',
#  'veg',
#  'Scandinavian_lox',
#  'johnny_cake',
#  'Persian_melon',
#  'cake_mix',
#  'lasagne',
#  'rum_baba',
#  'sugar_cookie',
#  'salami',
#  'triple_cream',
#  'hushpuppy',
#  'porc',
#  'pemican',
#  'vermicelli',
#  'Dungeness_crab',
#  'French_pancake',
#  'forequarter',
#  'mackerel',
#  'hoecake',
#  'frankfurter',
#  'cocoa_powder',
#  'rib_roast',
#  'smoked_haddock',
#  'pea_bean',
#  'flatbread',
#  'French_endive',
#  'mozzarella',
#  'swedish_turnip',
#  'anise_cookie',
#  'ash_cake',
#  'eater',
#  'cookie',
#  'white_chocolate',
#  'double_cream',
#  'Alaska_crab',
#  'alligator_pear',
#  'juneberry',
#  'frijole',
#  'natal_plum',
#  'sieva_bean',
#  'cherimoya',
#  'cross_bun',
#  'hen',
#  'grated_cheese',
#  'pocket_bread',
#  'Melba_toast',
#  'hotdog_bun',
#  'bouchee',
#  'german_pancake',
#  'mouton',
#  'New_York_strip',
#  'jackfruit',
#  'cardoon',
#  'sockeye_salmon',
#  'garden_truck',
#  'durian',
#  'crab_apple',
#  'Boston_brown_bread',
#  'Canadian_bacon',
#  'bowtie_pasta',
#  'Jonathan',
#  'meat',
#  'Japanese_plum',
#  'sultana',
#  'salt_cod',
#  'citrus',
#  'shell_bean',
#  'ghee',
#  'satsuma',
#  'muscatel',
#  'bridecake',
#  'bamboo_shoot',
#  'dried_apricot',
#  'bartlett_pear',
#  'Bermuda_onion',
#  'brisling',
#  'hush_puppy',
#  'corn_flake',
#  'bialy',
#  'monkfish',
#  'toad-in-the-hole',
#  'nutmeg_melon',
#  'beluga_caviar',
#  'haricots_verts',
#  'Indian_mustard',
#  'Swiss_chard',
#  'collards',
#  'Valencia_orange',
#  'vinifera_grape',
#  'calamari',
#  'croissant',
#  'pumpkin',
#  'citron',
#  'cheesecake',
#  'wintergreen',
#  'Kentucky_wonder_bean',
#  'pulassan',
#  'legume',
#  'gnocchi',
#  'Macoun',
#  'blood_pudding',
#  'quark_cheese',
#  'flank',
#  'spud',
#  'ecrevisse',
#  'edible_bean',
#  'egg_noodle',
#  'dolphinfish',
#  'dika_bread',
#  'brain',
#  'doughnut',
#  'venison',
#  'pita',
#  'fava_bean',
#  'cut_of_mutton',
#  'cruller',
#  'blade',
#  'lima_bean',
#  'green_bean',
#  'sugarberry',
#  'mango',
#  'beef',
#  'lingonberry',
#  'blintz',
#  'flapcake',
#  'tostada',
#  'coral',
#  'English_sole',
#  'game',
#  'pickerel',
#  'casaba',
#  'smoked_salmon',
#  'salmon_loaf',
#  'ladyfinger',
#  'takeout_food',
#  'octopus',
#  'scarlet_runner_bean',
#  'Nova_Scotia_salmon',
#  'Stayman_Winesap',
#  'roaster',
#  'caviare',
#  'English_runner_bean',
#  'sweetsop',
#  'husk_tomato',
#  'cut',
#  'hake',
#  'crookneck',
#  'baked_goods',
#  'Nova_style_salmon',
#  'chinook_salmon',
#  'rockfish',
#  'rambotan',
#  'raised_doughnut',
#  'round_clam',
#  'Pearmain',
#  'eggplant',
#  'nut_bread',
#  'Jerusalem_artichoke',
#  'apple',
#  'brown_butter',
#  'soya_bean',
#  'Pippin',
#  'fettuccini',
#  "Bramley's_Seedling",
#  'shad_roe',
#  'leftovers',
#  'graham_bread',
#  'ham',
#  'bilberry',
#  'buffalofish',
#  'vegetable_marrow',
#  'root_vegetable',
#  'striper',
#  'sloe',
#  'green_goods',
#  'pond_apple',
#  'mudcat',
#  'eating_apple',
#  'lansat',
#  'hotdog',
#  'Winesap',
#  'snow_pea',
#  'Rock_Cornish_hen',
#  'gobbet',
#  'roe',
#  'pork_sausage',
#  'date_bar',
#  'tournedos',
#  'bok_choy',
#  'drawn_butter',
#  'noodle',
#  'hand_cheese',
#  'spinach_beet',
#  'onion_bagel',
#  'Chateaubriand',
#  'string_cheese',
#  'lime',
#  'pemmican',
#  'dumpling',
#  'star_fruit',
#  'poultry',
#  'butterhead_lettuce',
#  'mombin',
#  'confit',
#  'variety_meat',
#  'tomatillo',
#  'porkchop',
#  'Meuniere_butter',
#  'broad_bean',
#  'bean_sprout',
#  'veggie',
#  'mince_pie',
#  'drop_biscuit',
#  'freshwater_fish',
#  'penne',
#  'parsnip',
#  'hamburger_bun',
#  'kiss',
#  "calf's_brain",
#  'chiffon_cake',
#  'sweet_pepper',
#  'halal',
#  'kiwi',
#  'chopped_steak',
#  'crape',
#  'mostaccioli',
#  'puff',
#  'medlar',
#  'scarlet_runner',
#  'chipotle',
#  "shepherd's_pie",
#  'custard_apple',
#  'graham_cracker',
#  'bran_flake',
#  'cheddar',
#  'fresh_bean',
#  'Spanish_lime',
#  'puffer',
#  'french-fried_potatoes',
#  'navy_bean',
#  'Oven_Stuffer_Roaster',
#  'delicatessen_food',
#  'saddle_of_lamb',
#  'sourdough_bread',
#  'litchi',
#  'litchee',
#  'Japanese_crab',
#  'spareribs',
#  'TV_dinner',
#  'chorizo',
#  'bok_choi',
#  'loose-leaf_lettuce',
#  'bell_apple',
#  'kitembilla',
#  'sardine',
#  'prune',
#  'sirloin_steak',
#  'Armerican_cheddar',
#  'turkey',
#  'English_muffin',
#  'leg',
#  'ratafia',
#  'rhubarb_pie',
#  'vegetable',
#  'spaghettini',
#  'taro_root',
#  'genip',
#  'club_steak',
#  'pork_loin',
#  'Scotch_pancake',
#  'ceriman',
#  "pigs'_knuckles",
#  'zwieback',
#  'split-pea',
#  'jellyroll',
#  'date',
#  'bass',
#  'civet_bean',
#  'pitahaya',
#  'Vidalia_onion',
#  'fettuccine_Alfredo',
#  'sweet_potato',
#  'soursop',
#  'sprinkles',
#  'cut_of_pork',
#  'quandang',
#  'finnan_haddock',
#  'pineapple',
#  'scrod',
#  'vegetable_oyster',
#  'seedcake',
#  'cinnamon_bun',
#  'lentil',
#  'tea_bread',
#  'dodger',
#  'wonton',
#  'loquat',
#  'yellow_squash',
#  'Victoria_plum',
#  'rump_roast',
#  'lichi',
#  'goose',
#  'baguette',
#  'sticky_bun',
#  'pfannkuchen',
#  'slop',
#  'fry_bread',
#  'baking-powder_biscuit',
#  'collard_greens',
#  'Limburger',
#  'elver',
#  'round',
#  'honeycomb_tripe',
#  'ocean_perch',
#  'tunny',
#  'Roquefort',
#  'lasagna',
#  'chilli',
#  'pulasan',
#  'boysenberry',
#  'pin_bone',
#  'hamburger',
#  'brisket',
#  'sole',
#  'cuke',
#  'avocado',
#  'melon',
#  'dog',
#  'breast_of_veal',
#  'romaine',
#  'plate',
#  'Muenster',
#  'refrigerator_cookie',
#  'blade_apple',
#  'whortleberry',
#  'sugar_loaf',
#  'quahaug',
#  'sorb',
#  'kiwi_fruit',
#  'pasta',
#  'snail',
#  'bitter_chocolate',
#  'corn_muffin',
#  'gammon',
#  'date_bread',
#  'hare',
#  'foreshank',
#  'watercress',
#  'rat_cheese',
#  'raisin_cookie',
#  'Twinkie',
#  'West_Indian_cherry',
#  'blackheart_cherry',
#  'purple_onion',
#  'coconut',
#  'aguacate',
#  'jalapeno_pepper',
#  'biscuit',
#  'home_fries',
#  'buffalo',
#  'spring_onion',
#  'plum_tomato',
#  'sausage',
#  'French_loaf',
#  'crabmeat',
#  'simnel',
#  'teaberry',
#  'shortbread',
#  'seedless_raisin',
#  'squash',
#  'Fordhooks',
#  'cereal',
#  'escarole',
#  'Baldwin',
#  'roast_pork',
#  'sunfish',
#  'haslet',
#  'eel',
#  'Liederkranz',
#  'loaf_sugar',
#  'sucker',
#  'applesauce_cake',
#  'sausage_meat',
#  'frankfurter_bun',
#  'tabasco',
#  'light_bread',
#  'bluepoint',
#  'pumpernickel',
#  'deep-dish_pie',
#  'cornpone',
#  'sweet_cherry',
#  'neck',
#  'Emmenthal',
#  'swordfish',
#  'dewberry',
#  'meatloaf',
#  'gumbo',
#  'ginger_snap',
#  'lemonade_mix',
#  'process_cheese',
#  'date-nut_bread',
#  'throat_sweetbread',
#  'damson',
#  'polenta',
#  'chou',
#  'lox',
#  'picnic_shoulder',
#  'salad_green',
#  'tortilla',
#  'delicatessen',
#  'Emmentaler',
#  'squash_pie',
#  'weakfish',
#  'winter_melon',
#  'celery',
#  'melon_ball',
#  'bear_claw',
#  'whitefish',
#  'liver_sausage',
#  'coconut_cake',
#  'French_bean',
#  'white_potato',
#  'temple_orange',
#  'giblet',
#  'jerk',
#  'honeydew_melon',
#  'rainbow_trout',
#  'jalapeno',
#  'Florence_fennel',
#  'ravioli',
#  'Brie',
#  'lamb-chop',
#  'wax_bean',
#  'fatback',
#  'salsify',
#  'Swedish_rye',
#  'hot_pepper',
#  'sprat',
#  'red_snapper',
#  'skillet_corn_bread',
#  'Italian_bread',
#  'escallop',
#  'roll',
#  'clarified_butter',
#  'baked_potato',
#  'squab',
#  'common_bean',
#  'dowdy',
#  'gray_mullet',
#  'quail',
#  'shin',
#  'blood_sausage',
#  'health_food',
#  'garden_pea',
#  'sapodilla',
#  'salmon_trout',
#  'Chinese_jujube',
#  'halibut',
#  'green_groceries',
#  'black_cherry',
#  'cut_of_lamb',
#  'linguine',
#  'plum',
#  'limpa',
#  'serviceberry',
#  'sorrel',
#  'Rome_Beauty',
#  'cornbread',
#  'poulet',
#  'bully_beef',
#  'picnic_ham',
#  'soda_cracker',
#  'lambchop',
#  'loganberry',
#  'corn_tash',
#  'oxheart',
#  'cupcake',
#  'pasty',
#  'raw_meat',
#  'chitlins',
#  'raspberry',
#  'bologna',
#  'windfall',
#  'filet_mignon',
#  'jak',
#  'Delicious',
#  'muffin',
#  'baguet',
#  'blue_crab',
#  'soybean',
#  'nectarine',
#  'ziti',
#  'undercut',
#  'matzah_ball',
#  'buttermilk_biscuit',
#  'Delmonico_steak',
#  'roast_veal',
#  'matzoh_ball',
#  'sweet_orange',
#  'tangerine',
#  'pascal_celery',
#  'naan',
#  'coffee_roll',
#  'Bibb_lettuce',
#  'almond_crescent',
#  'pie_shell',
#  'kai_apple',
#  'chicory_escarole',
#  'bismark',
#  'stone_crab',
#  'croaker',
#  'Empire',
#  'edible_fruit',
#  'scallion',
#  'solanaceous_vegetable',
#  'gluten_bread',
#  'takeout',
#  'scorzonera',
#  'citrus_fruit',
#  'avocado_pear',
#  'macaroon',
#  'ketembilla',
#  'granola',
#  'bitter_orange',
#  'panfish',
#  'buttermilk_pancake',
#  'porterhouse',
#  'Barbados_gooseberry',
#  'king_crab',
#  'latke',
#  'fedelline',
#  'squid',
#  'celery_root',
#  'cos',
#  'kidney_pie',
#  'cocoa_butter',
#  'tater',
#  'courgette',
#  'pear',
#  'pimento',
#  'baklava',
#  'common_sorrel',
#  'winter_crookneck_squash',
#  'mascarpone',
#  'beef_tenderloin',
#  'scrapple',
#  'green_pea',
#  'rigatoni',
#  'soda_biscuit',
#  'crawfish',
#  'turnip_cabbage',
#  'chine',
#  'persimmon',
#  'soft-shell_crab',
#  'spatchcock',
#  'saddle',
#  'staff_of_life',
#  'lemon_butter',
#  'blueberry_pie',
#  'prosciutto',
#  'red_salmon',
#  'fettuccine',
#  'liver_pudding',
#  'Danish_blue',
#  'genipap_fruit',
#  'black_currant',
#  'chitterlings',
#  'dry_cereal',
#  'Paschal_celery',
#  'white_bread',
#  'Host',
#  'yak_butter',
#  'white_cake',
#  'prune_cake',
#  'rusk',
#  'cracked-wheat_bread',
#  'chapatti',
#  'knackwurst',
#  'bittersweet_chocolate',
#  'chocolate_candy',
#  'linguini',
#  'molasses_cookie',
#  'muscat_grape',
#  'rutabaga',
#  'beef_jerky',
#  'celtuce',
#  "calf's_tongue",
#  'rib',
#  'beef_patty',
#  'doughboy',
#  'wheatflake',
#  'shad',
#  'whole_meal_bread',
#  'savarin',
#  'mamey',
#  'Madeira_cake',
#  'dove',
#  'cantaloupe',
#  'tripe',
#  'field_soybean',
#  "lamb's-quarter",
#  'finnan',
#  'chili',
#  'pot_cheese',
#  'Cortland',
#  'smoked_herring',
#  'beef_loin',
#  'hot_cake',
#  'chinook',
#  'Kentucky_wonder',
#  'anjou',
#  'fries',
#  'butter_bean',
#  'lemon',
#  'yoghourt',
#  'scrag_end',
#  'cocoyam',
#  'amarelle',
#  'steak_and_kidney_pie',
#  'smoked_mackerel',
#  'sugar_apple',
#  'fastnacht',
#  'side_of_meat',
#  'dessert_apple',
#  'French_fritter',
#  'rugelach',
#  'freshwater_bream',
#  'yellow_bean',
#  'plantain',
#  'sowbelly',
#  'mutton_chop',
#  'couverture',
#  'greengage',
#  'vol-au-vent',
#  'Gruyere',
#  'gingerbread_man',
#  'Cornish_pasty',
#  'organs',
#  'layer_cake',
#  'freestone',
#  'muskellunge',
#  'pork_tenderloin',
#  'cheese',
#  'lake_herring',
#  'garambulla',
#  'knockwurst',
#  'swede',
#  'blueberry',
#  'cherry_tomato',
#  'Irish_soda_bread',
#  'rollmops',
#  'Emmental',
#  'salad_burnet',
#  'patty_shell',
#  'whitebait',
#  'oysters_Rockefeller',
#  'buttercup_squash',
#  'tamarindo',
#  'Brussels_biscuit',
#  'green',
#  'Stayman',
#  'fricandeau',
#  'ham_hock',
#  'garden_cress',
#  'kippered_herring',
#  'bartlett',
#  'cheddar_cheese',
#  'surinam_cherry',
#  'timbale',
#  'gem',
#  'romaine_lettuce',
#  'hamburger_roll',
#  'pattypan_squash',
#  'cappelletti',
#  'litchi_nut',
#  'patty',
#  'chickpea',
#  'butternut_squash',
#  'coffee_cake',
#  'beach_plum',
#  'Toll_House_cookie',
#  'seckel_pear',
#  'T-bone_steak',
#  'sea_scallop',
#  'pheasant',
#  'matzoh',
#  'breadstuff',
#  'grouper',
#  'spinach',
#  'leg_of_lamb',
#  'gingersnap',
#  'pastry',
#  'flannel-cake',
#  'American_smelt',
#  'cinnamon_snail',
#  'bear_paw',
#  'coffee_ring',
#  'tomalley',
#  'yellow_mombin',
#  'napoleon',
#  'pomelo',
#  'mustard',
#  'cohoe',
#  'largemouth_bass',
#  'apricot_bar',
#  'tomato',
#  'savoy_cabbage',
#  'leechee',
#  'cut_of_beef',
#  'coco_plum',
#  'cushaw',
#  'cinnamon_toast',
#  'honey_cake',
#  'jujube',
#  ...]

# %%
### Output: {} with keys (location, budget, ambience, misc)
